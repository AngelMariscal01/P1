# %%
import gzip
import ast
import json
import pandas as pd
from datetime import datetime

# %%
def crearDFJSON(ruta):
    data = []
    with gzip.open(ruta, 'rb') as f:
        for line in f:
            data.append(json.loads(line))
    f.close
    return pd.DataFrame(data)

def crearDFAST(ruta):
    data = []
    with gzip.open(ruta, 'rb') as f:
        for line in f:
            data.append(ast.literal_eval(line.decode('utf-8')))
    f.close
    return pd.DataFrame(data)

def desanidarDF(df, columna):
    df_desanidado = df.explode(columna)
    return df_desanidado

def desanidar(df, columna):
    dfDesanidado = pd.json_normalize(df[columna])
    df = df.reset_index(drop=True)
    df = pd.concat([df, dfDesanidado], axis=1)
    df = df.drop(columna, axis=1)
    return df

# %%
steamGamesDF = crearDFJSON('steam_games.json.gz')
userReviews = crearDFAST('user_reviews.json.gz')
usersItems = crearDFAST('users_items.json.gz')

# %%
#eliminar nulos e ajustar el indice
steamGamesDF = steamGamesDF.dropna().reset_index(drop=True)

columnas_elimnar = ['url', 'reviews_url', 'early_access', 'genres', 'app_name', 'developer']
tipos = {'publisher':str, 'title':str, 'tags':str, 'specs':str, 'price':float, 'id':str}

steamGamesDF = steamGamesDF.drop(columnas_elimnar, axis=1)
steamGamesDF = desanidarDF(steamGamesDF, 'tags')
steamGamesDF = desanidarDF(steamGamesDF, 'specs')
steamGamesDF = steamGamesDF.reset_index(drop=True)

steamGamesDF['price'] = steamGamesDF['price'].replace('Free To Play', 0)
steamGamesDF['price'] = steamGamesDF['price'].replace('Free to Play', 0)
steamGamesDF['price'] = steamGamesDF['price'].replace('Free', 0)
steamGamesDF['price'] = steamGamesDF['price'].replace('Free Demo', 0)
steamGamesDF['price'] = steamGamesDF['price'].replace('Play for Free!', 0)
steamGamesDF['price'] = steamGamesDF['price'].replace('Install Now', 0)
steamGamesDF['price'] = steamGamesDF['price'].replace('Play WARMACHINE: Tactics Demo', 0)
steamGamesDF['pruserReviewsice'] = steamGamesDF['price'].replace('Free Mod', 0)
steamGamesDF['price'] = steamGamesDF['price'].replace('Play Now', 0)
steamGamesDF['price'] = steamGamesDF['price'].replace('Free HITMAN™ Holiday Pack', 0)
steamGamesDF['price'] = steamGamesDF['price'].replace('Play the Demo', 0)
steamGamesDF['price'] = steamGamesDF['price'].replace('Third-party', 0)

steamGamesDF = steamGamesDF.astype(tipos)
steamGamesDF['price'] = pd.to_numeric(steamGamesDF['price'], errors='coerce')
#steamGamesDF['release_date'] =  pd.to_datetime(steamGamesDF['release_date'], errors='coerce', infer_datetime_format=True)

steamGamesDF.columns = ['Publicador','Titulo','FechaLanzamiento','Etiqueta', 'Especificaciones', 'Precio', 'IdItem']
# Out:
# /tmp/ipykernel_3652/2042944034.py:23: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   steamGamesDF['price'] = steamGamesDF['price'].replace('Third-party', 0)

# %%
userReviews = desanidarDF(userReviews, 'reviews')
userReviews=desanidar(userReviews, 'reviews')

columnas_elimnar = ['funny', 'last_edited', 'helpful', 'user_url']
userReviews = userReviews.drop(columnas_elimnar, axis=1).reset_index(drop=True)

userReviews.columns = ['IdUsuario', 'Fecha', 'IdItem', 'Recomendado', 'Critica']
userReviews = userReviews.dropna()

# %%
columnas_elimnar = ['steam_id', 'user_url']
usersItems = usersItems.drop(columnas_elimnar, axis=1).reset_index(drop=True)

usersItems = desanidarDF(usersItems, 'items')
usersItems = desanidar(usersItems, 'items')
usersItems = usersItems.dropna()

columnas_elimnar = ['playtime_2weeks', 'items_count']
usersItems = usersItems.drop(columnas_elimnar, axis=1).reset_index(drop=True)

# %%
steamGamesDF
# Out:
#        Publicador               Titulo FechaLanzamiento     Etiqueta  \
# 0       Kotoshiro  Lost Summoner Kitty       2018-01-04     Strategy
# 1       Kotoshiro  Lost Summoner Kitty       2018-01-04       Action
# 2       Kotoshiro  Lost Summoner Kitty       2018-01-04        Indie
# 3       Kotoshiro  Lost Summoner Kitty       2018-01-04       Casual
# 4       Kotoshiro  Lost Summoner Kitty       2018-01-04   Simulation
# ...           ...                  ...              ...          ...
# 592996   SIXNAILS  EXIT 2 - Directions       2017-09-02  Atmospheric
# 592997   SIXNAILS  EXIT 2 - Directions       2017-09-02  Atmospheric
# 592998   SIXNAILS  EXIT 2 - Directions       2017-09-02     Relaxing
# 592999   SIXNAILS  EXIT 2 - Directions       2017-09-02     Relaxing
# 593000   SIXNAILS  EXIT 2 - Directions       2017-09-02     Relaxing
#
#           Especificaciones  Precio  IdItem
# 0            Single-player    4.99  761140
# 1            Single-player    4.99  761140
# 2            Single-player    4.99  761140
# 3            Single-player    4.99  761140
# 4            Single-player    4.99  761140
# ...                    ...     ...     ...
# 592996  Steam Achievements    4.99  658870
# 592997         Steam Cloud    4.99  658870
# 592998       Single-player    4.99  658870
# 592999  Steam Achievements    4.99  658870
# 593000         Steam Cloud    4.99  658870
#
# [593001 rows x 7 columns]

# %%
userReviews
# Out:
#                IdUsuario                      Fecha  IdItem Recomendado  \
# 0      76561197970982479   Posted November 5, 2011.    1250        True
# 1      76561197970982479      Posted July 15, 2011.   22200        True
# 2      76561197970982479     Posted April 21, 2011.   43110        True
# 3                js41637      Posted June 24, 2014.  251610        True
# 4                js41637  Posted September 8, 2013.  227300        True
# ...                  ...                        ...     ...         ...
# 59328  76561198312638244            Posted July 10.      70        True
# 59329  76561198312638244             Posted July 8.  362890        True
# 59330        LydiaMorley             Posted July 3.  273110        True
# 59331        LydiaMorley            Posted July 20.     730        True
# 59332        LydiaMorley             Posted July 2.     440        True
#
#                                                  Critica
# 0      Simple yet with great replayability. In my opi...
# 1                   It's unique and worth a playthrough.
# 2      Great atmosphere. The gunplay can be a bit chu...
# 3      I know what you think when you see this title ...
# 4      For a simple (it's actually not all that simpl...
# ...                                                  ...
# 59328  a must have classic from steam definitely wort...
# 59329  this game is a perfect remake of the original ...
# 59330  had so much fun plaing this and collecting res...
# 59331                                                 :D
# 59332                                     so much fun :D
#
# [59305 rows x 5 columns]

# %%
usersItems
# Out:
#                    user_id item_id                      item_name  \
# 0        76561197970982479      10                 Counter-Strike
# 1        76561197970982479      20          Team Fortress Classic
# 2        76561197970982479      30                  Day of Defeat
# 3        76561197970982479      40             Deathmatch Classic
# 4        76561197970982479      50      Half-Life: Opposing Force
# ...                    ...     ...                            ...
# 5153204  76561198329548331  346330                   BrainBread 2
# 5153205  76561198329548331  373330                    All Is Dust
# 5153206  76561198329548331  388490  One Way To Die: Steam Edition
# 5153207  76561198329548331  521570          You Have 10 Seconds 2
# 5153208  76561198329548331  519140                     Minds Eyes
#
#          playtime_forever
# 0                     6.0
# 1                     0.0
# 2                     7.0
# 3                     0.0
# 4                     0.0
# ...                   ...
# 5153204               0.0
# 5153205               0.0
# 5153206               3.0
# 5153207               4.0
# 5153208               3.0
#
# [5153209 rows x 4 columns]
